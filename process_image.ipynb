# %%
# Use python 3.7+

import numpy as np
import pandas as pd
from pathlib import Path
import PIL
from PIL import Image, ExifTags
import torch
from torchvision.transforms import ToTensor
import shutil
from typing import Optional, List
from dataclasses import dataclass
import folium

@dataclass
class Lat_Lon:
    lat: float
    lon: float

# %%
# A callable class that creates the destination bin directories
# based on start, stop and step temperature arguments and can then
# copy a file from a source directory to a destination bin directory.

class Bin_Agent:
    
    def _create_bin_names(self):
        """Make the bin directory names."""
        bin_cnt = 2 + (self.stop - self.start) // self.step
        self.bin_names = [""] * bin_cnt
        self.bin_names[0] = "le_{}".format(self.start)
        self.bin_names[1:] = ["gt_{}".format(i) 
                             for i in range(self.start, self.stop + 1, self.step)]
        
    def _create_destination_bin_directories(self):
        """Create the directories under base_path if they do not exist."""
        for dir_name in self.bin_names:
            new_dir = self.base_path / dir_name
            new_dir.mkdir(exist_ok=True)    
            print("Directory {} created or already exists.".format(new_dir))
            
    def _get_destination_bin(self, max_temp : float) -> str:
        """Given a maximum temperature, find the destination bin"""
        bin_name = None

        if max_temp > self.stop:
            bin_name = self.bin_names[-1]
        elif max_temp <= self.start:
            bin_name = self.bin_names[0]
        else:
            bin_idx = int(max_temp) // self.step + 1
            bin_name = self.bin_names[bin_idx]

        return bin_name
           
    def __init__(self, base_path : Path, start : int, stop : int, step : int):
        assert step > 0, "Step must be greater than 0"
        assert start < stop, "Stop must be greater than Start"
        assert (stop - start) % step == 0, "Difference between start and stop must be an exact multiple of step"
        
        self.base_path = base_path
        self.start = start
        self.stop = stop
        self.step = step
        self.bin_names = []
        
        self._create_bin_names()
        self._create_destination_bin_directories()
    
    def __call__(self, tif_file : Path, max_temp : float) -> Path:
        """Given a tif file and its maximum temperature, find the destination path"""
        tif_file_name = tif_file.name
        bin_name = self._get_destination_bin(max_temp)
        return self.base_path / bin_name / tif_file_name

# %%
temper_path = Path("rjpeg_temperature_16bit_0-80")
geo_path = Path("rjpeg_modified_0-80_gps_mod")
base_path = Path(".")
temper_path, geo_path, base_path
# Out:
# (PosixPath('rjpeg_temperature_16bit_0-80'),
#  PosixPath('rjpeg_modified_0-80_gps_mod'),
#  PosixPath('.'))

# %%
# Create the bin agent with our input parameters.
bin_agent = Bin_Agent(Path("."),0,80,20)
# Out:
# Directory le_0 created or already exists.
# Directory gt_0 created or already exists.
# Directory gt_20 created or already exists.
# Directory gt_40 created or already exists.
# Directory gt_60 created or already exists.
# Directory gt_80 created or already exists.

# %%
# Test bin_agent()
#bin_agent(temper_path/"DJI_0035_0.tif", 25.9999)

# %%
def get_tif_file_paths(src_path : Path) -> pd.DataFrame:
    """Get the *.tif filenames"""
    tif_file_paths = sorted(src_path.glob("*.tif"))
    print("Number of files = {}".format(len(tif_file_paths)))
    return pd.DataFrame({"src" : tif_file_paths})

# %%
df = get_tif_file_paths(temper_path); df
# Out:
# Number of files = 406
#                                              src
# 0      rjpeg_temperature_16bit_0-80/DJI_0034.tif
# 1      rjpeg_temperature_16bit_0-80/DJI_0035.tif
# 2    rjpeg_temperature_16bit_0-80/DJI_0035_0.tif
# 3      rjpeg_temperature_16bit_0-80/DJI_0036.tif
# 4    rjpeg_temperature_16bit_0-80/DJI_0036_0.tif
# 5      rjpeg_temperature_16bit_0-80/DJI_0037.tif
# 6    rjpeg_temperature_16bit_0-80/DJI_0037_0.tif
# 7      rjpeg_temperature_16bit_0-80/DJI_0038.tif
# 8    rjpeg_temperature_16bit_0-80/DJI_0038_0.tif
# 9      rjpeg_temperature_16bit_0-80/DJI_0039.tif
# 10   rjpeg_temperature_16bit_0-80/DJI_0039_0.tif
# 11     rjpeg_temperature_16bit_0-80/DJI_0040.tif
# 12   rjpeg_temperature_16bit_0-80/DJI_0040_0.tif
# 13     rjpeg_temperature_16bit_0-80/DJI_0041.tif
# 14   rjpeg_temperature_16bit_0-80/DJI_0041_0.tif
# 15     rjpeg_temperature_16bit_0-80/DJI_0042.tif
# 16   rjpeg_temperature_16bit_0-80/DJI_0042_0.tif
# 17     rjpeg_temperature_16bit_0-80/DJI_0043.tif
# 18   rjpeg_temperature_16bit_0-80/DJI_0043_0.tif
# 19     rjpeg_temperature_16bit_0-80/DJI_0044.tif
# 20   rjpeg_temperature_16bit_0-80/DJI_0044_0.tif
# 21     rjpeg_temperature_16bit_0-80/DJI_0045.tif
# 22   rjpeg_temperature_16bit_0-80/DJI_0045_0.tif
# 23     rjpeg_temperature_16bit_0-80/DJI_0046.tif
# 24   rjpeg_temperature_16bit_0-80/DJI_0046_0.tif
# 25     rjpeg_temperature_16bit_0-80/DJI_0047.tif
# 26   rjpeg_temperature_16bit_0-80/DJI_0047_0.tif
# 27     rjpeg_temperature_16bit_0-80/DJI_0048.tif
# 28   rjpeg_temperature_16bit_0-80/DJI_0048_0.tif
# 29     rjpeg_temperature_16bit_0-80/DJI_0049.tif
# ..                                           ...
# 376    rjpeg_temperature_16bit_0-80/DJI_0371.tif
# 377    rjpeg_temperature_16bit_0-80/DJI_0372.tif
# 378    rjpeg_temperature_16bit_0-80/DJI_0373.tif
# 379    rjpeg_temperature_16bit_0-80/DJI_0374.tif
# 380    rjpeg_temperature_16bit_0-80/DJI_0375.tif
# 381    rjpeg_temperature_16bit_0-80/DJI_0376.tif
# 382    rjpeg_temperature_16bit_0-80/DJI_0377.tif
# 383    rjpeg_temperature_16bit_0-80/DJI_0378.tif
# 384    rjpeg_temperature_16bit_0-80/DJI_0379.tif
# 385    rjpeg_temperature_16bit_0-80/DJI_0380.tif
# 386    rjpeg_temperature_16bit_0-80/DJI_0381.tif
# 387    rjpeg_temperature_16bit_0-80/DJI_0382.tif
# 388    rjpeg_temperature_16bit_0-80/DJI_0383.tif
# 389    rjpeg_temperature_16bit_0-80/DJI_0384.tif
# 390    rjpeg_temperature_16bit_0-80/DJI_0385.tif
# 391    rjpeg_temperature_16bit_0-80/DJI_0386.tif
# 392    rjpeg_temperature_16bit_0-80/DJI_0387.tif
# 393    rjpeg_temperature_16bit_0-80/DJI_0388.tif
# 394    rjpeg_temperature_16bit_0-80/DJI_0389.tif
# 395    rjpeg_temperature_16bit_0-80/DJI_0390.tif
# 396    rjpeg_temperature_16bit_0-80/DJI_0391.tif
# 397    rjpeg_temperature_16bit_0-80/DJI_0392.tif
# 398    rjpeg_temperature_16bit_0-80/DJI_0393.tif
# 399    rjpeg_temperature_16bit_0-80/DJI_0394.tif
# 400    rjpeg_temperature_16bit_0-80/DJI_0395.tif
# 401    rjpeg_temperature_16bit_0-80/DJI_0396.tif
# 402    rjpeg_temperature_16bit_0-80/DJI_0397.tif
# 403    rjpeg_temperature_16bit_0-80/DJI_0398.tif
# 404    rjpeg_temperature_16bit_0-80/DJI_0399.tif
# 405    rjpeg_temperature_16bit_0-80/DJI_0400.tif
#
# [406 rows x 1 columns]

# %%
def get_max_temperature_from_tif_file(tif_file : Path) -> float:
    """Read a temperature tif file and get the maximum temperature"""   

    max_temp = np.NAN
    
    try:
        # Open the tif image file using PIL and then convert it to a torch.tensor().
        with PIL.Image.open(tif_file) as tif_img:
            tensor_tif = ToTensor()(tif_img)

        # Get the max() value of the tensor (returns a single item tensor like tensor(3.))
        # The item() call gets the scaler item from the tensor (e.g. 3. from tensor(3.)).
            max_temp = tensor_tif.max().item()
    except:
        max_temp = np.NAN
        
    return max_temp

def get_jpg_path(tif_file : Path) -> Path:
    """Create the corresponding jpg filename from the tif filename"""
    
    jpg_file_suffix = ".jpg"
    
    # Stem gives the filename without the parent path or the suffix 
    # e.g. Path("/hello/world.tif") => "world"
    file_name_stem = tif_file.stem
    jpg_file = geo_path / (file_name_stem + jpg_file_suffix)
    return jpg_file

# %%
# Find the max temperature (in °C)
df["max_temp"] = df["src"].map(lambda fp: get_max_temperature_from_tif_file(fp)); df
# Out:
#                                              src   max_temp
# 0      rjpeg_temperature_16bit_0-80/DJI_0034.tif  20.862015
# 1      rjpeg_temperature_16bit_0-80/DJI_0035.tif  22.079849
# 2    rjpeg_temperature_16bit_0-80/DJI_0035_0.tif  18.603956
# 3      rjpeg_temperature_16bit_0-80/DJI_0036.tif  22.776861
# 4    rjpeg_temperature_16bit_0-80/DJI_0036_0.tif  17.483416
# 5      rjpeg_temperature_16bit_0-80/DJI_0037.tif  23.150208
# 6    rjpeg_temperature_16bit_0-80/DJI_0037_0.tif  18.687483
# 7      rjpeg_temperature_16bit_0-80/DJI_0038.tif  23.681208
# 8    rjpeg_temperature_16bit_0-80/DJI_0038_0.tif  18.352951
# 9      rjpeg_temperature_16bit_0-80/DJI_0039.tif  24.367432
# 10   rjpeg_temperature_16bit_0-80/DJI_0039_0.tif  17.342438
# 11     rjpeg_temperature_16bit_0-80/DJI_0040.tif  26.037483
# 12   rjpeg_temperature_16bit_0-80/DJI_0040_0.tif  17.764757
# 13     rjpeg_temperature_16bit_0-80/DJI_0041.tif  26.913971
# 14   rjpeg_temperature_16bit_0-80/DJI_0041_0.tif  17.511585
# 15     rjpeg_temperature_16bit_0-80/DJI_0042.tif  29.425615
# 16   rjpeg_temperature_16bit_0-80/DJI_0042_0.tif  18.185257
# 17     rjpeg_temperature_16bit_0-80/DJI_0043.tif  30.324572
# 18   rjpeg_temperature_16bit_0-80/DJI_0043_0.tif  16.748091
# 19     rjpeg_temperature_16bit_0-80/DJI_0044.tif  31.068062
# 20   rjpeg_temperature_16bit_0-80/DJI_0044_0.tif  76.497498
# 21     rjpeg_temperature_16bit_0-80/DJI_0045.tif  31.831064
# 22   rjpeg_temperature_16bit_0-80/DJI_0045_0.tif  51.026695
# 23     rjpeg_temperature_16bit_0-80/DJI_0046.tif  32.320530
# 24   rjpeg_temperature_16bit_0-80/DJI_0046_0.tif  84.199295
# 25     rjpeg_temperature_16bit_0-80/DJI_0047.tif  33.751991
# 26   rjpeg_temperature_16bit_0-80/DJI_0047_0.tif  87.315895
# 27     rjpeg_temperature_16bit_0-80/DJI_0048.tif  37.917240
# 28   rjpeg_temperature_16bit_0-80/DJI_0048_0.tif  89.829903
# 29     rjpeg_temperature_16bit_0-80/DJI_0049.tif  35.355663
# ..                                           ...        ...
# 376    rjpeg_temperature_16bit_0-80/DJI_0371.tif  28.897747
# 377    rjpeg_temperature_16bit_0-80/DJI_0372.tif  28.417908
# 378    rjpeg_temperature_16bit_0-80/DJI_0373.tif  36.960407
# 379    rjpeg_temperature_16bit_0-80/DJI_0374.tif  31.634666
# 380    rjpeg_temperature_16bit_0-80/DJI_0375.tif  31.683800
# 381    rjpeg_temperature_16bit_0-80/DJI_0376.tif  36.913528
# 382    rjpeg_temperature_16bit_0-80/DJI_0377.tif  41.329876
# 383    rjpeg_temperature_16bit_0-80/DJI_0378.tif  47.770512
# 384    rjpeg_temperature_16bit_0-80/DJI_0379.tif  46.889278
# 385    rjpeg_temperature_16bit_0-80/DJI_0380.tif  48.773159
# 386    rjpeg_temperature_16bit_0-80/DJI_0381.tif  38.033386
# 387    rjpeg_temperature_16bit_0-80/DJI_0382.tif  34.088982
# 388    rjpeg_temperature_16bit_0-80/DJI_0383.tif  27.553833
# 389    rjpeg_temperature_16bit_0-80/DJI_0384.tif  30.672165
# 390    rjpeg_temperature_16bit_0-80/DJI_0385.tif  33.171925
# 391    rjpeg_temperature_16bit_0-80/DJI_0386.tif  33.147686
# 392    rjpeg_temperature_16bit_0-80/DJI_0387.tif  31.265474
# 393    rjpeg_temperature_16bit_0-80/DJI_0388.tif  25.284060
# 394    rjpeg_temperature_16bit_0-80/DJI_0389.tif  23.442598
# 395    rjpeg_temperature_16bit_0-80/DJI_0390.tif  24.472599
# 396    rjpeg_temperature_16bit_0-80/DJI_0391.tif  22.160519
# 397    rjpeg_temperature_16bit_0-80/DJI_0392.tif  21.675537
# 398    rjpeg_temperature_16bit_0-80/DJI_0393.tif  21.783512
# 399    rjpeg_temperature_16bit_0-80/DJI_0394.tif  21.756529
# 400    rjpeg_temperature_16bit_0-80/DJI_0395.tif  21.025248
# 401    rjpeg_temperature_16bit_0-80/DJI_0396.tif  19.766939
# 402    rjpeg_temperature_16bit_0-80/DJI_0397.tif  20.643959
# 403    rjpeg_temperature_16bit_0-80/DJI_0398.tif  20.096727
# 404    rjpeg_temperature_16bit_0-80/DJI_0399.tif  19.684320
# 405    rjpeg_temperature_16bit_0-80/DJI_0400.tif  21.567446
#
# [406 rows x 2 columns]

# %%
# Check if any tif file is missing a max_temp.
df_fail = df[df["max_temp"].isna()] ; df_fail
# Out:
# Empty DataFrame
# Columns: [src, max_temp]
# Index: []

# %%
# Find the appropriate destination directory, based on max temperature
df["dest_path"] = df.apply(lambda r: bin_agent(r["src"], r["max_temp"]), axis="columns"); df
# Out:
#                                              src   max_temp  \
# 0      rjpeg_temperature_16bit_0-80/DJI_0034.tif  20.862015
# 1      rjpeg_temperature_16bit_0-80/DJI_0035.tif  22.079849
# 2    rjpeg_temperature_16bit_0-80/DJI_0035_0.tif  18.603956
# 3      rjpeg_temperature_16bit_0-80/DJI_0036.tif  22.776861
# 4    rjpeg_temperature_16bit_0-80/DJI_0036_0.tif  17.483416
# 5      rjpeg_temperature_16bit_0-80/DJI_0037.tif  23.150208
# 6    rjpeg_temperature_16bit_0-80/DJI_0037_0.tif  18.687483
# 7      rjpeg_temperature_16bit_0-80/DJI_0038.tif  23.681208
# 8    rjpeg_temperature_16bit_0-80/DJI_0038_0.tif  18.352951
# 9      rjpeg_temperature_16bit_0-80/DJI_0039.tif  24.367432
# 10   rjpeg_temperature_16bit_0-80/DJI_0039_0.tif  17.342438
# 11     rjpeg_temperature_16bit_0-80/DJI_0040.tif  26.037483
# 12   rjpeg_temperature_16bit_0-80/DJI_0040_0.tif  17.764757
# 13     rjpeg_temperature_16bit_0-80/DJI_0041.tif  26.913971
# 14   rjpeg_temperature_16bit_0-80/DJI_0041_0.tif  17.511585
# 15     rjpeg_temperature_16bit_0-80/DJI_0042.tif  29.425615
# 16   rjpeg_temperature_16bit_0-80/DJI_0042_0.tif  18.185257
# 17     rjpeg_temperature_16bit_0-80/DJI_0043.tif  30.324572
# 18   rjpeg_temperature_16bit_0-80/DJI_0043_0.tif  16.748091
# 19     rjpeg_temperature_16bit_0-80/DJI_0044.tif  31.068062
# 20   rjpeg_temperature_16bit_0-80/DJI_0044_0.tif  76.497498
# 21     rjpeg_temperature_16bit_0-80/DJI_0045.tif  31.831064
# 22   rjpeg_temperature_16bit_0-80/DJI_0045_0.tif  51.026695
# 23     rjpeg_temperature_16bit_0-80/DJI_0046.tif  32.320530
# 24   rjpeg_temperature_16bit_0-80/DJI_0046_0.tif  84.199295
# 25     rjpeg_temperature_16bit_0-80/DJI_0047.tif  33.751991
# 26   rjpeg_temperature_16bit_0-80/DJI_0047_0.tif  87.315895
# 27     rjpeg_temperature_16bit_0-80/DJI_0048.tif  37.917240
# 28   rjpeg_temperature_16bit_0-80/DJI_0048_0.tif  89.829903
# 29     rjpeg_temperature_16bit_0-80/DJI_0049.tif  35.355663
# ..                                           ...        ...
# 376    rjpeg_temperature_16bit_0-80/DJI_0371.tif  28.897747
# 377    rjpeg_temperature_16bit_0-80/DJI_0372.tif  28.417908
# 378    rjpeg_temperature_16bit_0-80/DJI_0373.tif  36.960407
# 379    rjpeg_temperature_16bit_0-80/DJI_0374.tif  31.634666
# 380    rjpeg_temperature_16bit_0-80/DJI_0375.tif  31.683800
# 381    rjpeg_temperature_16bit_0-80/DJI_0376.tif  36.913528
# 382    rjpeg_temperature_16bit_0-80/DJI_0377.tif  41.329876
# 383    rjpeg_temperature_16bit_0-80/DJI_0378.tif  47.770512
# 384    rjpeg_temperature_16bit_0-80/DJI_0379.tif  46.889278
# 385    rjpeg_temperature_16bit_0-80/DJI_0380.tif  48.773159
# 386    rjpeg_temperature_16bit_0-80/DJI_0381.tif  38.033386
# 387    rjpeg_temperature_16bit_0-80/DJI_0382.tif  34.088982
# 388    rjpeg_temperature_16bit_0-80/DJI_0383.tif  27.553833
# 389    rjpeg_temperature_16bit_0-80/DJI_0384.tif  30.672165
# 390    rjpeg_temperature_16bit_0-80/DJI_0385.tif  33.171925
# 391    rjpeg_temperature_16bit_0-80/DJI_0386.tif  33.147686
# 392    rjpeg_temperature_16bit_0-80/DJI_0387.tif  31.265474
# 393    rjpeg_temperature_16bit_0-80/DJI_0388.tif  25.284060
# 394    rjpeg_temperature_16bit_0-80/DJI_0389.tif  23.442598
# 395    rjpeg_temperature_16bit_0-80/DJI_0390.tif  24.472599
# 396    rjpeg_temperature_16bit_0-80/DJI_0391.tif  22.160519
# 397    rjpeg_temperature_16bit_0-80/DJI_0392.tif  21.675537
# 398    rjpeg_temperature_16bit_0-80/DJI_0393.tif  21.783512
# 399    rjpeg_temperature_16bit_0-80/DJI_0394.tif  21.756529
# 400    rjpeg_temperature_16bit_0-80/DJI_0395.tif  21.025248
# 401    rjpeg_temperature_16bit_0-80/DJI_0396.tif  19.766939
# 402    rjpeg_temperature_16bit_0-80/DJI_0397.tif  20.643959
# 403    rjpeg_temperature_16bit_0-80/DJI_0398.tif  20.096727
# 404    rjpeg_temperature_16bit_0-80/DJI_0399.tif  19.684320
# 405    rjpeg_temperature_16bit_0-80/DJI_0400.tif  21.567446
#
#                 dest_path
# 0      gt_20/DJI_0034.tif
# 1      gt_20/DJI_0035.tif
# 2     gt_0/DJI_0035_0.tif
# 3      gt_20/DJI_0036.tif
# 4     gt_0/DJI_0036_0.tif
# 5      gt_20/DJI_0037.tif
# 6     gt_0/DJI_0037_0.tif
# 7      gt_20/DJI_0038.tif
# 8     gt_0/DJI_0038_0.tif
# 9      gt_20/DJI_0039.tif
# 10    gt_0/DJI_0039_0.tif
# 11     gt_20/DJI_0040.tif
# 12    gt_0/DJI_0040_0.tif
# 13     gt_20/DJI_0041.tif
# 14    gt_0/DJI_0041_0.tif
# 15     gt_20/DJI_0042.tif
# 16    gt_0/DJI_0042_0.tif
# 17     gt_20/DJI_0043.tif
# 18    gt_0/DJI_0043_0.tif
# 19     gt_20/DJI_0044.tif
# 20   gt_60/DJI_0044_0.tif
# 21     gt_20/DJI_0045.tif
# 22   gt_40/DJI_0045_0.tif
# 23     gt_20/DJI_0046.tif
# 24   gt_80/DJI_0046_0.tif
# 25     gt_20/DJI_0047.tif
# 26   gt_80/DJI_0047_0.tif
# 27     gt_20/DJI_0048.tif
# 28   gt_80/DJI_0048_0.tif
# 29     gt_20/DJI_0049.tif
# ..                    ...
# 376    gt_20/DJI_0371.tif
# 377    gt_20/DJI_0372.tif
# 378    gt_20/DJI_0373.tif
# 379    gt_20/DJI_0374.tif
# 380    gt_20/DJI_0375.tif
# 381    gt_20/DJI_0376.tif
# 382    gt_40/DJI_0377.tif
# 383    gt_40/DJI_0378.tif
# 384    gt_40/DJI_0379.tif
# 385    gt_40/DJI_0380.tif
# 386    gt_20/DJI_0381.tif
# 387    gt_20/DJI_0382.tif
# 388    gt_20/DJI_0383.tif
# 389    gt_20/DJI_0384.tif
# 390    gt_20/DJI_0385.tif
# 391    gt_20/DJI_0386.tif
# 392    gt_20/DJI_0387.tif
# 393    gt_20/DJI_0388.tif
# 394    gt_20/DJI_0389.tif
# 395    gt_20/DJI_0390.tif
# 396    gt_20/DJI_0391.tif
# 397    gt_20/DJI_0392.tif
# 398    gt_20/DJI_0393.tif
# 399    gt_20/DJI_0394.tif
# 400    gt_20/DJI_0395.tif
# 401     gt_0/DJI_0396.tif
# 402    gt_20/DJI_0397.tif
# 403    gt_20/DJI_0398.tif
# 404     gt_0/DJI_0399.tif
# 405    gt_20/DJI_0400.tif
#
# [406 rows x 3 columns]

# %%
# Check the number of tif files that should be copied to each bin.
dfg = df["dest_path"].copy()
dfg["dest_bin"] = dfg.map(lambda p: p.parts[-2])
dfg.groupby(["dest_bin"]).count()
# Out:
# dest_bin
# gt_0      89
# gt_20    250
# gt_40     34
# gt_60     13
# gt_80     20
# Name: dest_path, dtype: int64

# %%
# Copy the tif files from source to destination.
df.apply(lambda r: shutil.copy2(src=r["src"], dst=r["dest_path"]), axis="columns")
# Out:
# 0        gt_20/DJI_0034.tif
# 1        gt_20/DJI_0035.tif
# 2       gt_0/DJI_0035_0.tif
# 3        gt_20/DJI_0036.tif
# 4       gt_0/DJI_0036_0.tif
# 5        gt_20/DJI_0037.tif
# 6       gt_0/DJI_0037_0.tif
# 7        gt_20/DJI_0038.tif
# 8       gt_0/DJI_0038_0.tif
# 9        gt_20/DJI_0039.tif
# 10      gt_0/DJI_0039_0.tif
# 11       gt_20/DJI_0040.tif
# 12      gt_0/DJI_0040_0.tif
# 13       gt_20/DJI_0041.tif
# 14      gt_0/DJI_0041_0.tif
# 15       gt_20/DJI_0042.tif
# 16      gt_0/DJI_0042_0.tif
# 17       gt_20/DJI_0043.tif
# 18      gt_0/DJI_0043_0.tif
# 19       gt_20/DJI_0044.tif
# 20     gt_60/DJI_0044_0.tif
# 21       gt_20/DJI_0045.tif
# 22     gt_40/DJI_0045_0.tif
# 23       gt_20/DJI_0046.tif
# 24     gt_80/DJI_0046_0.tif
# 25       gt_20/DJI_0047.tif
# 26     gt_80/DJI_0047_0.tif
# 27       gt_20/DJI_0048.tif
# 28     gt_80/DJI_0048_0.tif
# 29       gt_20/DJI_0049.tif
#                ...
# 376      gt_20/DJI_0371.tif
# 377      gt_20/DJI_0372.tif
# 378      gt_20/DJI_0373.tif
# 379      gt_20/DJI_0374.tif
# 380      gt_20/DJI_0375.tif
# 381      gt_20/DJI_0376.tif
# 382      gt_40/DJI_0377.tif
# 383      gt_40/DJI_0378.tif
# 384      gt_40/DJI_0379.tif
# 385      gt_40/DJI_0380.tif
# 386      gt_20/DJI_0381.tif
# 387      gt_20/DJI_0382.tif
# 388      gt_20/DJI_0383.tif
# 389      gt_20/DJI_0384.tif
# 390      gt_20/DJI_0385.tif
# 391      gt_20/DJI_0386.tif
# 392      gt_20/DJI_0387.tif
# 393      gt_20/DJI_0388.tif
# 394      gt_20/DJI_0389.tif
# 395      gt_20/DJI_0390.tif
# 396      gt_20/DJI_0391.tif
# 397      gt_20/DJI_0392.tif
# 398      gt_20/DJI_0393.tif
# 399      gt_20/DJI_0394.tif
# 400      gt_20/DJI_0395.tif
# 401       gt_0/DJI_0396.tif
# 402      gt_20/DJI_0397.tif
# 403      gt_20/DJI_0398.tif
# 404       gt_0/DJI_0399.tif
# 405      gt_20/DJI_0400.tif
# Length: 406, dtype: object

# %%
# Filter rows which have a max_temp greater than 60°C. 
# Make a copy of filtered rows (otherwise the slice refers to the original dataframe)
df60 = df[df.max_temp > 60].copy(); df60
# Out:
#                                              src    max_temp  \
# 20   rjpeg_temperature_16bit_0-80/DJI_0044_0.tif   76.497498
# 24   rjpeg_temperature_16bit_0-80/DJI_0046_0.tif   84.199295
# 26   rjpeg_temperature_16bit_0-80/DJI_0047_0.tif   87.315895
# 28   rjpeg_temperature_16bit_0-80/DJI_0048_0.tif   89.829903
# 30   rjpeg_temperature_16bit_0-80/DJI_0049_0.tif   85.095657
# 32   rjpeg_temperature_16bit_0-80/DJI_0050_0.tif   78.216194
# 34   rjpeg_temperature_16bit_0-80/DJI_0051_0.tif   74.424072
# 51     rjpeg_temperature_16bit_0-80/DJI_0060.tif   62.097160
# 53     rjpeg_temperature_16bit_0-80/DJI_0061.tif   98.318275
# 55     rjpeg_temperature_16bit_0-80/DJI_0062.tif  104.347237
# 56   rjpeg_temperature_16bit_0-80/DJI_0062_0.tif   68.563972
# 57     rjpeg_temperature_16bit_0-80/DJI_0063.tif  105.548203
# 59     rjpeg_temperature_16bit_0-80/DJI_0064.tif   84.830574
# 61     rjpeg_temperature_16bit_0-80/DJI_0065.tif   98.087791
# 63     rjpeg_temperature_16bit_0-80/DJI_0066.tif  136.816116
# 65     rjpeg_temperature_16bit_0-80/DJI_0067.tif  141.678391
# 66   rjpeg_temperature_16bit_0-80/DJI_0067_0.tif   60.861012
# 67     rjpeg_temperature_16bit_0-80/DJI_0068.tif  144.954285
# 69     rjpeg_temperature_16bit_0-80/DJI_0069.tif  141.000427
# 71     rjpeg_temperature_16bit_0-80/DJI_0070.tif  147.870499
# 73     rjpeg_temperature_16bit_0-80/DJI_0071.tif  151.563705
# 75     rjpeg_temperature_16bit_0-80/DJI_0072.tif  142.104309
# 77     rjpeg_temperature_16bit_0-80/DJI_0073.tif  144.198273
# 79     rjpeg_temperature_16bit_0-80/DJI_0074.tif  147.307068
# 81     rjpeg_temperature_16bit_0-80/DJI_0075.tif   69.224442
# 96     rjpeg_temperature_16bit_0-80/DJI_0090.tif   69.827309
# 97     rjpeg_temperature_16bit_0-80/DJI_0091.tif   85.194962
# 98     rjpeg_temperature_16bit_0-80/DJI_0092.tif   78.716148
# 99     rjpeg_temperature_16bit_0-80/DJI_0093.tif   77.853172
# 100    rjpeg_temperature_16bit_0-80/DJI_0094.tif   86.299850
# 102    rjpeg_temperature_16bit_0-80/DJI_0096.tif   76.007980
# 127    rjpeg_temperature_16bit_0-80/DJI_0121.tif   68.251053
# 142    rjpeg_temperature_16bit_0-80/DJI_0136.tif   72.089180
#
#                 dest_path
# 20   gt_60/DJI_0044_0.tif
# 24   gt_80/DJI_0046_0.tif
# 26   gt_80/DJI_0047_0.tif
# 28   gt_80/DJI_0048_0.tif
# 30   gt_80/DJI_0049_0.tif
# 32   gt_60/DJI_0050_0.tif
# 34   gt_60/DJI_0051_0.tif
# 51     gt_60/DJI_0060.tif
# 53     gt_80/DJI_0061.tif
# 55     gt_80/DJI_0062.tif
# 56   gt_60/DJI_0062_0.tif
# 57     gt_80/DJI_0063.tif
# 59     gt_80/DJI_0064.tif
# 61     gt_80/DJI_0065.tif
# 63     gt_80/DJI_0066.tif
# 65     gt_80/DJI_0067.tif
# 66   gt_60/DJI_0067_0.tif
# 67     gt_80/DJI_0068.tif
# 69     gt_80/DJI_0069.tif
# 71     gt_80/DJI_0070.tif
# 73     gt_80/DJI_0071.tif
# 75     gt_80/DJI_0072.tif
# 77     gt_80/DJI_0073.tif
# 79     gt_80/DJI_0074.tif
# 81     gt_60/DJI_0075.tif
# 96     gt_60/DJI_0090.tif
# 97     gt_80/DJI_0091.tif
# 98     gt_60/DJI_0092.tif
# 99     gt_60/DJI_0093.tif
# 100    gt_80/DJI_0094.tif
# 102    gt_60/DJI_0096.tif
# 127    gt_60/DJI_0121.tif
# 142    gt_60/DJI_0136.tif

# %%
# reset the index to 0
df60.index = pd.RangeIndex(len(df60.index)); df60
# Out:
#                                             src    max_temp  \
# 0   rjpeg_temperature_16bit_0-80/DJI_0044_0.tif   76.497498
# 1   rjpeg_temperature_16bit_0-80/DJI_0046_0.tif   84.199295
# 2   rjpeg_temperature_16bit_0-80/DJI_0047_0.tif   87.315895
# 3   rjpeg_temperature_16bit_0-80/DJI_0048_0.tif   89.829903
# 4   rjpeg_temperature_16bit_0-80/DJI_0049_0.tif   85.095657
# 5   rjpeg_temperature_16bit_0-80/DJI_0050_0.tif   78.216194
# 6   rjpeg_temperature_16bit_0-80/DJI_0051_0.tif   74.424072
# 7     rjpeg_temperature_16bit_0-80/DJI_0060.tif   62.097160
# 8     rjpeg_temperature_16bit_0-80/DJI_0061.tif   98.318275
# 9     rjpeg_temperature_16bit_0-80/DJI_0062.tif  104.347237
# 10  rjpeg_temperature_16bit_0-80/DJI_0062_0.tif   68.563972
# 11    rjpeg_temperature_16bit_0-80/DJI_0063.tif  105.548203
# 12    rjpeg_temperature_16bit_0-80/DJI_0064.tif   84.830574
# 13    rjpeg_temperature_16bit_0-80/DJI_0065.tif   98.087791
# 14    rjpeg_temperature_16bit_0-80/DJI_0066.tif  136.816116
# 15    rjpeg_temperature_16bit_0-80/DJI_0067.tif  141.678391
# 16  rjpeg_temperature_16bit_0-80/DJI_0067_0.tif   60.861012
# 17    rjpeg_temperature_16bit_0-80/DJI_0068.tif  144.954285
# 18    rjpeg_temperature_16bit_0-80/DJI_0069.tif  141.000427
# 19    rjpeg_temperature_16bit_0-80/DJI_0070.tif  147.870499
# 20    rjpeg_temperature_16bit_0-80/DJI_0071.tif  151.563705
# 21    rjpeg_temperature_16bit_0-80/DJI_0072.tif  142.104309
# 22    rjpeg_temperature_16bit_0-80/DJI_0073.tif  144.198273
# 23    rjpeg_temperature_16bit_0-80/DJI_0074.tif  147.307068
# 24    rjpeg_temperature_16bit_0-80/DJI_0075.tif   69.224442
# 25    rjpeg_temperature_16bit_0-80/DJI_0090.tif   69.827309
# 26    rjpeg_temperature_16bit_0-80/DJI_0091.tif   85.194962
# 27    rjpeg_temperature_16bit_0-80/DJI_0092.tif   78.716148
# 28    rjpeg_temperature_16bit_0-80/DJI_0093.tif   77.853172
# 29    rjpeg_temperature_16bit_0-80/DJI_0094.tif   86.299850
# 30    rjpeg_temperature_16bit_0-80/DJI_0096.tif   76.007980
# 31    rjpeg_temperature_16bit_0-80/DJI_0121.tif   68.251053
# 32    rjpeg_temperature_16bit_0-80/DJI_0136.tif   72.089180
#
#                dest_path
# 0   gt_60/DJI_0044_0.tif
# 1   gt_80/DJI_0046_0.tif
# 2   gt_80/DJI_0047_0.tif
# 3   gt_80/DJI_0048_0.tif
# 4   gt_80/DJI_0049_0.tif
# 5   gt_60/DJI_0050_0.tif
# 6   gt_60/DJI_0051_0.tif
# 7     gt_60/DJI_0060.tif
# 8     gt_80/DJI_0061.tif
# 9     gt_80/DJI_0062.tif
# 10  gt_60/DJI_0062_0.tif
# 11    gt_80/DJI_0063.tif
# 12    gt_80/DJI_0064.tif
# 13    gt_80/DJI_0065.tif
# 14    gt_80/DJI_0066.tif
# 15    gt_80/DJI_0067.tif
# 16  gt_60/DJI_0067_0.tif
# 17    gt_80/DJI_0068.tif
# 18    gt_80/DJI_0069.tif
# 19    gt_80/DJI_0070.tif
# 20    gt_80/DJI_0071.tif
# 21    gt_80/DJI_0072.tif
# 22    gt_80/DJI_0073.tif
# 23    gt_80/DJI_0074.tif
# 24    gt_60/DJI_0075.tif
# 25    gt_60/DJI_0090.tif
# 26    gt_80/DJI_0091.tif
# 27    gt_60/DJI_0092.tif
# 28    gt_60/DJI_0093.tif
# 29    gt_80/DJI_0094.tif
# 30    gt_60/DJI_0096.tif
# 31    gt_60/DJI_0121.tif
# 32    gt_60/DJI_0136.tif

# %%
# Compute the jpg filepath from the source tif filepath.
df60["jpg"] = df60["src"].map(lambda fp: get_jpg_path(fp)); df60
# Out:
#                                             src    max_temp  \
# 0   rjpeg_temperature_16bit_0-80/DJI_0044_0.tif   76.497498
# 1   rjpeg_temperature_16bit_0-80/DJI_0046_0.tif   84.199295
# 2   rjpeg_temperature_16bit_0-80/DJI_0047_0.tif   87.315895
# 3   rjpeg_temperature_16bit_0-80/DJI_0048_0.tif   89.829903
# 4   rjpeg_temperature_16bit_0-80/DJI_0049_0.tif   85.095657
# 5   rjpeg_temperature_16bit_0-80/DJI_0050_0.tif   78.216194
# 6   rjpeg_temperature_16bit_0-80/DJI_0051_0.tif   74.424072
# 7     rjpeg_temperature_16bit_0-80/DJI_0060.tif   62.097160
# 8     rjpeg_temperature_16bit_0-80/DJI_0061.tif   98.318275
# 9     rjpeg_temperature_16bit_0-80/DJI_0062.tif  104.347237
# 10  rjpeg_temperature_16bit_0-80/DJI_0062_0.tif   68.563972
# 11    rjpeg_temperature_16bit_0-80/DJI_0063.tif  105.548203
# 12    rjpeg_temperature_16bit_0-80/DJI_0064.tif   84.830574
# 13    rjpeg_temperature_16bit_0-80/DJI_0065.tif   98.087791
# 14    rjpeg_temperature_16bit_0-80/DJI_0066.tif  136.816116
# 15    rjpeg_temperature_16bit_0-80/DJI_0067.tif  141.678391
# 16  rjpeg_temperature_16bit_0-80/DJI_0067_0.tif   60.861012
# 17    rjpeg_temperature_16bit_0-80/DJI_0068.tif  144.954285
# 18    rjpeg_temperature_16bit_0-80/DJI_0069.tif  141.000427
# 19    rjpeg_temperature_16bit_0-80/DJI_0070.tif  147.870499
# 20    rjpeg_temperature_16bit_0-80/DJI_0071.tif  151.563705
# 21    rjpeg_temperature_16bit_0-80/DJI_0072.tif  142.104309
# 22    rjpeg_temperature_16bit_0-80/DJI_0073.tif  144.198273
# 23    rjpeg_temperature_16bit_0-80/DJI_0074.tif  147.307068
# 24    rjpeg_temperature_16bit_0-80/DJI_0075.tif   69.224442
# 25    rjpeg_temperature_16bit_0-80/DJI_0090.tif   69.827309
# 26    rjpeg_temperature_16bit_0-80/DJI_0091.tif   85.194962
# 27    rjpeg_temperature_16bit_0-80/DJI_0092.tif   78.716148
# 28    rjpeg_temperature_16bit_0-80/DJI_0093.tif   77.853172
# 29    rjpeg_temperature_16bit_0-80/DJI_0094.tif   86.299850
# 30    rjpeg_temperature_16bit_0-80/DJI_0096.tif   76.007980
# 31    rjpeg_temperature_16bit_0-80/DJI_0121.tif   68.251053
# 32    rjpeg_temperature_16bit_0-80/DJI_0136.tif   72.089180
#
#                dest_path                                         jpg
# 0   gt_60/DJI_0044_0.tif  rjpeg_modified_0-80_gps_mod/DJI_0044_0.jpg
# 1   gt_80/DJI_0046_0.tif  rjpeg_modified_0-80_gps_mod/DJI_0046_0.jpg
# 2   gt_80/DJI_0047_0.tif  rjpeg_modified_0-80_gps_mod/DJI_0047_0.jpg
# 3   gt_80/DJI_0048_0.tif  rjpeg_modified_0-80_gps_mod/DJI_0048_0.jpg
# 4   gt_80/DJI_0049_0.tif  rjpeg_modified_0-80_gps_mod/DJI_0049_0.jpg
# 5   gt_60/DJI_0050_0.tif  rjpeg_modified_0-80_gps_mod/DJI_0050_0.jpg
# 6   gt_60/DJI_0051_0.tif  rjpeg_modified_0-80_gps_mod/DJI_0051_0.jpg
# 7     gt_60/DJI_0060.tif    rjpeg_modified_0-80_gps_mod/DJI_0060.jpg
# 8     gt_80/DJI_0061.tif    rjpeg_modified_0-80_gps_mod/DJI_0061.jpg
# 9     gt_80/DJI_0062.tif    rjpeg_modified_0-80_gps_mod/DJI_0062.jpg
# 10  gt_60/DJI_0062_0.tif  rjpeg_modified_0-80_gps_mod/DJI_0062_0.jpg
# 11    gt_80/DJI_0063.tif    rjpeg_modified_0-80_gps_mod/DJI_0063.jpg
# 12    gt_80/DJI_0064.tif    rjpeg_modified_0-80_gps_mod/DJI_0064.jpg
# 13    gt_80/DJI_0065.tif    rjpeg_modified_0-80_gps_mod/DJI_0065.jpg
# 14    gt_80/DJI_0066.tif    rjpeg_modified_0-80_gps_mod/DJI_0066.jpg
# 15    gt_80/DJI_0067.tif    rjpeg_modified_0-80_gps_mod/DJI_0067.jpg
# 16  gt_60/DJI_0067_0.tif  rjpeg_modified_0-80_gps_mod/DJI_0067_0.jpg
# 17    gt_80/DJI_0068.tif    rjpeg_modified_0-80_gps_mod/DJI_0068.jpg
# 18    gt_80/DJI_0069.tif    rjpeg_modified_0-80_gps_mod/DJI_0069.jpg
# 19    gt_80/DJI_0070.tif    rjpeg_modified_0-80_gps_mod/DJI_0070.jpg
# 20    gt_80/DJI_0071.tif    rjpeg_modified_0-80_gps_mod/DJI_0071.jpg
# 21    gt_80/DJI_0072.tif    rjpeg_modified_0-80_gps_mod/DJI_0072.jpg
# 22    gt_80/DJI_0073.tif    rjpeg_modified_0-80_gps_mod/DJI_0073.jpg
# 23    gt_80/DJI_0074.tif    rjpeg_modified_0-80_gps_mod/DJI_0074.jpg
# 24    gt_60/DJI_0075.tif    rjpeg_modified_0-80_gps_mod/DJI_0075.jpg
# 25    gt_60/DJI_0090.tif    rjpeg_modified_0-80_gps_mod/DJI_0090.jpg
# 26    gt_80/DJI_0091.tif    rjpeg_modified_0-80_gps_mod/DJI_0091.jpg
# 27    gt_60/DJI_0092.tif    rjpeg_modified_0-80_gps_mod/DJI_0092.jpg
# 28    gt_60/DJI_0093.tif    rjpeg_modified_0-80_gps_mod/DJI_0093.jpg
# 29    gt_80/DJI_0094.tif    rjpeg_modified_0-80_gps_mod/DJI_0094.jpg
# 30    gt_60/DJI_0096.tif    rjpeg_modified_0-80_gps_mod/DJI_0096.jpg
# 31    gt_60/DJI_0121.tif    rjpeg_modified_0-80_gps_mod/DJI_0121.jpg
# 32    gt_60/DJI_0136.tif    rjpeg_modified_0-80_gps_mod/DJI_0136.jpg

# %%
def get_latitude_longitude(file_path : Path) -> Optional[Lat_Lon]:
    """Given a jpg file, return the latitude and longitude from the exif data"""
    
    def get_decimal_degrees_from_dms(dms, ref : str) -> float:
        """ Convert the rational64u format of degree, minute, second to decimal_degrees.
            Sample input dms format: ((51, 1), (45, 1), (1358029999, 50000000))
        """
        (dn, dd), (mn, md), (sn, sd) = dms
        d, m, s = float(dn)/dd, float(mn)/md, float(sn)/sd
        decimal_dms = d + m/60.0 + s/(3600.0)
        # If Latitude is 'S' or Longitude is 'W' , the degree sign should be negative
        return -decimal_dms if ref in ["S", "W"] else decimal_dms
        
    # Get the GPSInfo exif data
    try:
        image = PIL.Image.open(file_path)
        gps_exif = {PIL.ExifTags.TAGS[k]: v for k, v in image._getexif().items()
                        if k in PIL.ExifTags.TAGS and PIL.ExifTags.TAGS[k] == "GPSInfo"}

        if len(gps_exif) == 0:
            return None
    except:
        return None
    
    # Add the GPS tags.
    gps_exif_with_tags = {PIL.ExifTags.GPSTAGS[k]: v for k, v in gps_exif["GPSInfo"].items()
                            if k in PIL.ExifTags.GPSTAGS}
    
    # Verify presence of the required GPS tags.
    if not frozenset(["GPSLatitudeRef", "GPSLatitude", "GPSLongitudeRef", 
                     "GPSLongitude"]).issubset(gps_exif_with_tags.keys()):
        return None
    
    result = None
    # Convert the rational64u format of degree, minute, second to decimal_degrees 
    try:
        assert gps_exif_with_tags["GPSLatitudeRef"] in ["N", "S"], "LatitudeRef must be 'N' or 'S'"
        lat = get_decimal_degrees_from_dms(gps_exif_with_tags["GPSLatitude"], 
                                           gps_exif_with_tags["GPSLatitudeRef"])
        
        assert gps_exif_with_tags["GPSLongitudeRef"] in ["E", "W"], "LongitudeRef must be 'E' or 'W'"                                                          
        lon = get_decimal_degrees_from_dms(gps_exif_with_tags["GPSLongitude"], 
                                           gps_exif_with_tags["GPSLongitudeRef"])
    except:
        return None                                                        

    return Lat_Lon(round(lat, 6),  round(lon, 6))

# %%
# Get the latitude and longitude from the exif data of the jpg files
df60["coord"] = df60["jpg"].map(lambda fp: get_latitude_longitude(fp)); df60
# Out:
#                                             src    max_temp  \
# 0   rjpeg_temperature_16bit_0-80/DJI_0044_0.tif   76.497498
# 1   rjpeg_temperature_16bit_0-80/DJI_0046_0.tif   84.199295
# 2   rjpeg_temperature_16bit_0-80/DJI_0047_0.tif   87.315895
# 3   rjpeg_temperature_16bit_0-80/DJI_0048_0.tif   89.829903
# 4   rjpeg_temperature_16bit_0-80/DJI_0049_0.tif   85.095657
# 5   rjpeg_temperature_16bit_0-80/DJI_0050_0.tif   78.216194
# 6   rjpeg_temperature_16bit_0-80/DJI_0051_0.tif   74.424072
# 7     rjpeg_temperature_16bit_0-80/DJI_0060.tif   62.097160
# 8     rjpeg_temperature_16bit_0-80/DJI_0061.tif   98.318275
# 9     rjpeg_temperature_16bit_0-80/DJI_0062.tif  104.347237
# 10  rjpeg_temperature_16bit_0-80/DJI_0062_0.tif   68.563972
# 11    rjpeg_temperature_16bit_0-80/DJI_0063.tif  105.548203
# 12    rjpeg_temperature_16bit_0-80/DJI_0064.tif   84.830574
# 13    rjpeg_temperature_16bit_0-80/DJI_0065.tif   98.087791
# 14    rjpeg_temperature_16bit_0-80/DJI_0066.tif  136.816116
# 15    rjpeg_temperature_16bit_0-80/DJI_0067.tif  141.678391
# 16  rjpeg_temperature_16bit_0-80/DJI_0067_0.tif   60.861012
# 17    rjpeg_temperature_16bit_0-80/DJI_0068.tif  144.954285
# 18    rjpeg_temperature_16bit_0-80/DJI_0069.tif  141.000427
# 19    rjpeg_temperature_16bit_0-80/DJI_0070.tif  147.870499
# 20    rjpeg_temperature_16bit_0-80/DJI_0071.tif  151.563705
# 21    rjpeg_temperature_16bit_0-80/DJI_0072.tif  142.104309
# 22    rjpeg_temperature_16bit_0-80/DJI_0073.tif  144.198273
# 23    rjpeg_temperature_16bit_0-80/DJI_0074.tif  147.307068
# 24    rjpeg_temperature_16bit_0-80/DJI_0075.tif   69.224442
# 25    rjpeg_temperature_16bit_0-80/DJI_0090.tif   69.827309
# 26    rjpeg_temperature_16bit_0-80/DJI_0091.tif   85.194962
# 27    rjpeg_temperature_16bit_0-80/DJI_0092.tif   78.716148
# 28    rjpeg_temperature_16bit_0-80/DJI_0093.tif   77.853172
# 29    rjpeg_temperature_16bit_0-80/DJI_0094.tif   86.299850
# 30    rjpeg_temperature_16bit_0-80/DJI_0096.tif   76.007980
# 31    rjpeg_temperature_16bit_0-80/DJI_0121.tif   68.251053
# 32    rjpeg_temperature_16bit_0-80/DJI_0136.tif   72.089180
#
#                dest_path                                         jpg  \
# 0   gt_60/DJI_0044_0.tif  rjpeg_modified_0-80_gps_mod/DJI_0044_0.jpg
# 1   gt_80/DJI_0046_0.tif  rjpeg_modified_0-80_gps_mod/DJI_0046_0.jpg
# 2   gt_80/DJI_0047_0.tif  rjpeg_modified_0-80_gps_mod/DJI_0047_0.jpg
# 3   gt_80/DJI_0048_0.tif  rjpeg_modified_0-80_gps_mod/DJI_0048_0.jpg
# 4   gt_80/DJI_0049_0.tif  rjpeg_modified_0-80_gps_mod/DJI_0049_0.jpg
# 5   gt_60/DJI_0050_0.tif  rjpeg_modified_0-80_gps_mod/DJI_0050_0.jpg
# 6   gt_60/DJI_0051_0.tif  rjpeg_modified_0-80_gps_mod/DJI_0051_0.jpg
# 7     gt_60/DJI_0060.tif    rjpeg_modified_0-80_gps_mod/DJI_0060.jpg
# 8     gt_80/DJI_0061.tif    rjpeg_modified_0-80_gps_mod/DJI_0061.jpg
# 9     gt_80/DJI_0062.tif    rjpeg_modified_0-80_gps_mod/DJI_0062.jpg
# 10  gt_60/DJI_0062_0.tif  rjpeg_modified_0-80_gps_mod/DJI_0062_0.jpg
# 11    gt_80/DJI_0063.tif    rjpeg_modified_0-80_gps_mod/DJI_0063.jpg
# 12    gt_80/DJI_0064.tif    rjpeg_modified_0-80_gps_mod/DJI_0064.jpg
# 13    gt_80/DJI_0065.tif    rjpeg_modified_0-80_gps_mod/DJI_0065.jpg
# 14    gt_80/DJI_0066.tif    rjpeg_modified_0-80_gps_mod/DJI_0066.jpg
# 15    gt_80/DJI_0067.tif    rjpeg_modified_0-80_gps_mod/DJI_0067.jpg
# 16  gt_60/DJI_0067_0.tif  rjpeg_modified_0-80_gps_mod/DJI_0067_0.jpg
# 17    gt_80/DJI_0068.tif    rjpeg_modified_0-80_gps_mod/DJI_0068.jpg
# 18    gt_80/DJI_0069.tif    rjpeg_modified_0-80_gps_mod/DJI_0069.jpg
# 19    gt_80/DJI_0070.tif    rjpeg_modified_0-80_gps_mod/DJI_0070.jpg
# 20    gt_80/DJI_0071.tif    rjpeg_modified_0-80_gps_mod/DJI_0071.jpg
# 21    gt_80/DJI_0072.tif    rjpeg_modified_0-80_gps_mod/DJI_0072.jpg
# 22    gt_80/DJI_0073.tif    rjpeg_modified_0-80_gps_mod/DJI_0073.jpg
# 23    gt_80/DJI_0074.tif    rjpeg_modified_0-80_gps_mod/DJI_0074.jpg
# 24    gt_60/DJI_0075.tif    rjpeg_modified_0-80_gps_mod/DJI_0075.jpg
# 25    gt_60/DJI_0090.tif    rjpeg_modified_0-80_gps_mod/DJI_0090.jpg
# 26    gt_80/DJI_0091.tif    rjpeg_modified_0-80_gps_mod/DJI_0091.jpg
# 27    gt_60/DJI_0092.tif    rjpeg_modified_0-80_gps_mod/DJI_0092.jpg
# 28    gt_60/DJI_0093.tif    rjpeg_modified_0-80_gps_mod/DJI_0093.jpg
# 29    gt_80/DJI_0094.tif    rjpeg_modified_0-80_gps_mod/DJI_0094.jpg
# 30    gt_60/DJI_0096.tif    rjpeg_modified_0-80_gps_mod/DJI_0096.jpg
# 31    gt_60/DJI_0121.tif    rjpeg_modified_0-80_gps_mod/DJI_0121.jpg
# 32    gt_60/DJI_0136.tif    rjpeg_modified_0-80_gps_mod/DJI_0136.jpg
#
#                                       coord
# 0   Lat_Lon(lat=51.755092, lon=-100.896346)
# 1   Lat_Lon(lat=51.755092, lon=-100.896667)
# 2   Lat_Lon(lat=51.755092, lon=-100.896829)
# 3    Lat_Lon(lat=51.755092, lon=-100.89699)
# 4   Lat_Lon(lat=51.755093, lon=-100.897152)
# 5   Lat_Lon(lat=51.755093, lon=-100.897314)
# 6   Lat_Lon(lat=51.755093, lon=-100.897475)
# 7   Lat_Lon(lat=51.757544, lon=-100.896372)
# 8   Lat_Lon(lat=51.757544, lon=-100.896185)
# 9   Lat_Lon(lat=51.757544, lon=-100.896092)
# 10  Lat_Lon(lat=51.755093, lon=-100.899253)
# 11  Lat_Lon(lat=51.757544, lon=-100.895814)
# 12  Lat_Lon(lat=51.757544, lon=-100.895627)
# 13  Lat_Lon(lat=51.757545, lon=-100.895441)
# 14  Lat_Lon(lat=51.757544, lon=-100.895255)
# 15  Lat_Lon(lat=51.757544, lon=-100.895162)
# 16  Lat_Lon(lat=51.755092, lon=-100.900062)
# 17  Lat_Lon(lat=51.757545, lon=-100.894883)
# 18   Lat_Lon(lat=51.757545, lon=-100.89479)
# 19  Lat_Lon(lat=51.757545, lon=-100.894604)
# 20  Lat_Lon(lat=51.757544, lon=-100.894325)
# 21  Lat_Lon(lat=51.757544, lon=-100.894182)
# 22  Lat_Lon(lat=51.757543, lon=-100.894182)
# 23  Lat_Lon(lat=51.757543, lon=-100.894188)
# 24  Lat_Lon(lat=51.755219, lon=-100.899998)
# 25  Lat_Lon(lat=51.755219, lon=-100.897498)
# 26  Lat_Lon(lat=51.755219, lon=-100.897337)
# 27  Lat_Lon(lat=51.755219, lon=-100.897256)
# 28  Lat_Lon(lat=51.755219, lon=-100.897014)
# 29  Lat_Lon(lat=51.755219, lon=-100.896851)
# 30   Lat_Lon(lat=51.75522, lon=-100.896608)
# 31  Lat_Lon(lat=51.755349, lon=-100.897541)
# 32  Lat_Lon(lat=51.755349, lon=-100.899967)

# %%
# Check if any coordinate is missing.
df_fail = df60[df60["coord"].isna()]; df_fail
# Out:
# Empty DataFrame
# Columns: [src, max_temp, dest_path, jpg, coord]
# Index: []

# %%
# Create the map
tmap = folium.Map(location=[51.755, -100.896], zoom_start=12)
for ir in df60.iterrows():
    row = ir[1]
    temp = round(row["max_temp"], 2)
    lat = row["coord"].lat
    lon = row["coord"].lon
    folium.Marker(location=[lat, lon], 
        popup="Lat:{},Long:{},Temp={}°C".format(lat, lon, temp),
        icon=folium.Icon(color="red", icon="info-sign")).add_to(tmap)
    
tmap.save("hotspots60C_map.html")

display(tmap)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
